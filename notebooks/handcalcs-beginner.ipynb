# %%
import handcalcs.render

# %% [markdown]
# # Handcalcs testing

# %%
# %%render
# a = 3
# b = 5
# Out:
# $$
# \begin{aligned}
# a &= 3 \;
# \\
# b &= 5 \;
# \end{aligned}
# $$

# %%
# %%render
# c = a*b
# Out:
# $$
# \begin{aligned}
# c &= a \cdot b  = 3 \cdot 5 &= 15
# \end{aligned}
# $$

# %%
# %%render
# c = a*b
# Out:
# $$
# \begin{aligned}
# c &= a \cdot b  = 3 \cdot 5 &= 15
# \end{aligned}
# $$
