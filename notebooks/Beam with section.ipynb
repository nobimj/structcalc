# %%
from structcalc.calculations.beam import BeamInputs, simply_supported_beam_udl

inputs = BeamInputs(span=5.0, udl=20.0)
result = simply_supported_beam_udl(inputs)

for step in result.steps:
    print(step.title)
    print(step.formula)
    print(step.substitution)
    print(step.result)
