# %%
import handcalcs.render
import json
from pathlib import Path

# %%
with open("outputs/01_loads.json", "r") as f:
    loads = json.load(f)

F_d = loads["F_d"]

# %%
A = 2500        # mm2
f_y = 355       # MPa
gamma_M0 = 1.0

# %%
# %%render long
# N_Rd = A * f_y / gamma_M0 / 1000
# utilization = F_d / N_Rd
# Out:
# $$
# \begin{aligned}
# N_{Rd} &= A \cdot \frac{ f_{y} }{ \gamma_{M0} } \cdot \frac{1} { 1000 } \\&= 2500 \cdot \frac{ 355 }{ 1.000 } \cdot \frac{1} { 1000 } \\&= 887.500  \\
# \\
# \mathrm{utilization} &= \frac{ F_{d} }{ N_{Rd} } \\&= \frac{ 75.000 }{ 887.500 } \\&= 0.085  \\
# \end{aligned}
# $$
