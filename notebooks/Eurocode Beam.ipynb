# %%
from structcalc.eurocode.ec2_concrete.beams import EC2BeamInputs, required_tension_steel

inputs = EC2BeamInputs(
    width_mm=300,
    effective_depth_mm=450,
    fck_mpa=30,
    fyk_mpa=500,
    moment_ed_knm=150,
)

result = required_tension_steel(inputs)
result.required_steel_mm2
# Out:
# 851.8518518518518

# %%
from IPython.display import display, Math

for step in result.steps:
    print(step.title)
    display(Math(step.formula))
    display(Math(step.substitution))
    display(Math(step.result))
# Out:
# Design yield strength of reinforcement
# $\displaystyle f_{yd} = \frac{f_{yk}}{\gamma_s}$
# $\displaystyle f_{yd} = \frac{500}{1.15}$
# $\displaystyle f_{yd} = 434.78\ \text{N/mm}^2$
# Lever arm
# $\displaystyle z = 0.9d$
# $\displaystyle z = 0.9 \times 450$
# $\displaystyle z = 405.0\ \text{mm}$
# Required tension reinforcement
# $\displaystyle A_s = \frac{M_{Ed}}{f_{yd}z}$
# $\displaystyle A_s = \frac{150 \times 10^6}{434.78 \times 405.0}$
# $\displaystyle A_s = 851.9\ \text{mm}^2$
