# %%
from IPython.display import Image, display

from structcalc.graphics.rc_section import draw_rectangular_rc_section

path = draw_rectangular_rc_section(
    b_mm=300,
    h_mm=500,
    cover_mm=35,
    bar_diameter_mm=16,
    number_of_bars=4,
    output_path="outputs/figures/rc_section.png",
)

display(Image(filename=str(path)))
