# %%
import handcalcs.render
import json
from pathlib import Path

# %%
F_k = 50       # kN
gamma_F = 1.5

# %%
# %%render
# F_d = gamma_F * F_k
# Out:
# $$
# \begin{aligned}
# F_{d} &= \gamma_{F} \cdot F_{k}  = 1.500 \cdot 50 &= 75.000
# \end{aligned}
# $$

# %%
Path("outputs").mkdir(exist_ok=True)

with open("outputs/01_loads.json", "w") as f:
    json.dump(
        {
            "F_d": F_d
        },
        f,
        indent=4
    )
